# %%
import matplotlib.pyplot as plt
import pytesseract
import cv2 
import numpy as np 
import matplotlib.image as img
image = img.imread('BN18CTL.jpg')
plt.imshow(image)
from PIL import Image 
  
# creating a object 
# im = Image.open(r"BN18CTL.jpg") 
  
# im.show()

# %%
custom_config = r'--oem 3 --psm 6'
# text=pytesseract.image_to_string(image, config=custom_config)
text=pytesseract.image_to_string(image,lang='eng') #converts /image characters to string
print(text)

# %%
image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-106-2bc548bae4de> in <module>
# ----> 1 image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       2 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#       3 plt.show()
#
# error: OpenCV(4.5.1) c:\users\appveyor\appdata\local\temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<3,4,-1>,struct cv::impl::A0x206ccf44::Set<1,-1,-1>,struct cv::impl::A0x206ccf44::Set<0,2,5>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(image, config=custom_config)
# Out:
# 'BD\n6xSU832\n\x0c'

# %%
image=cv2.medianBlur(image,5)
plt.imshow(image)

# %%
image=cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
plt.imshow(image)

# %%
kernel = np.ones((5,5),np.uint8)
image=cv2.dilate(image, kernel, iterations = 1)
plt.imshow(image)

# %%
kernel = np.ones((5,5),np.uint8)
image=cv2.erode(image, kernel, iterations = 1)
plt.imshow(image)

# %%
kernel = np.ones((5,5),np.uint8)
image=cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
plt.imshow(image)

# %%
image=cv2.Canny(image, 100, 200)
plt.imshow(image)

# %%
coords = np.column_stack(np.where(image > 0))
angle = cv2.minAreaRect(coords)[-1]
if angle < -45:
    angle = -(90 + angle)
else:
    angle = -angle
(h, w) = image.shape[:2]
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, angle, 1.0)
image= cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
plt.imshow(image)

# %%
image=cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-5757781cc973> in <module>
# ----> 1 image=cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)
#       2 plt.imshow(image)
#
# NameError: name 'template' is not defined

# %%
image1 = cv2.imread('SA335C0.jpg')
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
ret, thresh4 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO)
cv2.imshow('Set to 0 Inverted', thresh4)
if cv2.waitKey(0) & 0xff == 27: 
    cv2.destroyAllWindows()

# %%
custom_config = r'--oem 3 --psm 6'
text=pytesseract.image_to_string(image, config=custom_config)
print(text)
# Out:
# [|e
